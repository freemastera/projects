# %%
#нужны установленные библиотеки requests, pandas, sqlalchemy, psycopg2(для связки sqlalchemy с postgres, вызывать необязательно)
import requests, sqlalchemy, pandas as pd
from sqlalchemy import create_engine

# %%
# Задаем параметры для URL для API
url_param = "https://api-metrika.yandex.net/stat/v1/data"

# %%
# Задаем параметры для API. Подробнее в справке https://yandex.ru/dev/metrika/doc/api2/api_v1/data.html
api_param = {
    'ids':44147844,
    'metrics':'ym:s:users,ym:s:visits,ym:s:pageviews,ym:s:bounceRate,ym:s:pageDepth,ym:s:avgVisitDurationSeconds',
    'dimensions':'ym:s:date,ym:s:<attribution>TrafficSource,ym:s:<attribution>SourceEngine',
    'date1':'yesterday',
    'date2':'yesterday',
    'sort':'ym:s:date',
    'accuracy':'full',
    'limit':100000
            }
# Задаем параметры header_params
header_params = {
    'GET': '/management/v1/counters HTTP/1.1',
    'Host': 'api-metrika.yandex.net',
    'Content-Type': 'application/x-yametrika+json'
            }

# %%
""" 
Так как у счетчика 44147844 публичный доступ, то токен не нужен. В противном случае его нужно будет указать
ACCESS_TOKEN = 'Ваш_токен'

И нужна дополнительная строка в header_params
'Authorization': 'OAuth ' + ACCESS_TOKEN 

Подробнее https://yandex.ru/dev/metrika/doc/api2/intro/authorization.html/
"""
# Out:
# " \nТак как у счетчика 44147844 публичный доступ, то токен не нужен. В противном случае его нужно будет указать\nACCESS_TOKEN = 'Ваш_токен'\n\nИ нужна дополнительная строка в header_params\n'Authorization': 'OAuth ' + ACCESS_TOKEN \n\nПодробнее https://yandex.ru/dev/metrika/doc/api2/intro/authorization.html/\n"

# %%
 # Отправляем get request (запрос GET)
response = requests.get(
    url_param,
    params=api_param,
    headers=header_params
        )

# %%
result = response.json()

# %%
json_data = result['data']

# %%
# Делаем плоскую таблицу в dataframe из json с большим уровнем вложенности. 
# Если уровень вложенности небольшой, можно обойтись pandas.json_normalize
dict_data = {}

# %%
for i in range(0, len(json_data)-1):
    dict_data[i] = {
                                'date':json_data[i]['dimensions'][0]['name'],
                                'traffic-source':json_data[i]['dimensions'][1]['name'],
                                'traffic-details':json_data[i]['dimensions'][2]['name'],
                                'users':json_data[i]['metrics'][0],
                                'visits':json_data[i]['metrics'][1],
                                'pageviews':json_data[i]['metrics'][2],
                                'bounceRate':json_data[i]['metrics'][3],
                                'pageDepth':json_data[i]['metrics'][4],
                                'avgVisitDurationSeconds':json_data[i]['metrics'][5]
                          }

# %%
dict_keys = dict_data[0].keys()

# %%
df = pd.DataFrame.from_dict(dict_data, orient='index',columns=dict_keys)

# %%
df
# Out:
#           date          traffic-source              traffic-details  users  \
# 0   2020-11-12        Internal traffic                         None   17.0
# 1   2020-11-12          Direct traffic                         None  147.0
# 2   2020-11-12            Link traffic             apps.shopify.com    1.0
# 3   2020-11-12            Link traffic                       be1.ru    1.0
# 4   2020-11-12            Link traffic          blog.saleslayer.com    1.0
# 5   2020-11-12            Link traffic                  chinafy.com    1.0
# 6   2020-11-12            Link traffic                   combot.org    2.0
# 7   2020-11-12            Link traffic    derdigitaleunternehmer.de    2.0
# 8   2020-11-12            Link traffic           destinonegocio.com    3.0
# 12     3.0        4.0   66.666667   1.333333                10.000000
# 13     1.0        1.0  100.000000   1.000000                 1.000000
# 14     1.0        4.0    0.000000   4.000000                20.000000
# 15     1.0        1.0  100.000000   1.000000                 2.000000
# 16     1.0        2.0    0.000000   2.000000                40.000000
# 17     1.0        1.0    0.000000   1.000000                23.000000
# 18     1.0        1.0  100.000000   1.000000                 3.000000
# 19     1.0        1.0  100.000000   1.000000                 2.000000
# 20     9.0       18.0   22.222222   2.000000               207.777778
# 21     1.0        1.0    0.000000   1.000000               612.000000
# 22     3.0        4.0   33.333333   1.333333                32.000000
# 23     1.0        1.0    0.000000   1.000000                15.000000
# 24     9.0       22.0   44.444444   2.444444               184.777778
# 25     1.0        1.0  100.000000   1.000000                 8.000000
# 26     2.0        2.0  100.000000   1.000000                 1.000000
# 27     1.0        1.0  100.000000   1.000000                 0.000000
# 28    46.0       62.0   60.869565   1.347826                53.239130
# 29     1.0        3.0    0.000000   3.000000                31.000000
# 30     1.0        1.0    0.000000   1.000000                15.000000
# 31     1.0        1.0    0.000000   1.000000                18.000000
# 32     1.0        1.0  100.000000   1.000000                 1.000000
# 33     1.0        1.0  100.000000   1.000000                 0.000000
# 34     6.0        7.0   33.333333   1.166667                65.166667
# 35     1.0        3.0    0.000000   3.000000               128.000000
# 36     6.0        8.0   50.000000   1.333333                18.333333
# 37     1.0        1.0  100.000000   1.000000                 1.000000
# 38     8.0       14.0   25.000000   1.750000                65.875000
# 39     1.0        1.0    0.000000   1.000000                15.000000
# 40     2.0        2.0   50.000000   1.000000                 7.500000
# 41     2.0        4.0   50.000000   2.000000                31.500000
# 42     3.0        4.0    0.000000   1.333333               430.333333
# 43    27.0       54.0   37.037037   2.000000                50.481481
# 44   161.0      281.0   25.465839   1.745342               133.211180
# 45    17.0       33.0   29.411765   1.941176                60.882353
# 46    11.0       13.0   45.454545   1.181818                11.000000
# 47     1.0        1.0  100.000000   1.000000                 0.000000
# 48     1.0        1.0  100.000000   1.000000                 8.000000
# 49     4.0        6.0   50.000000   1.500000                19.500000

# %%
# Делаем нужные нам преобразования. Например, добавим новый столбец 'avgUserPageviews(среднее кол-во просмотров на пользователя)' 
df['avgUserPageviews'] = df['pageviews'] / df['users']

# %%
#и округлим длинные значения
df[['bounceRate','pageDepth','avgVisitDurationSeconds','avgUserPageviews']] = df[['bounceRate','pageDepth','avgVisitDurationSeconds','avgUserPageviews']].round(1)

# %%
df
# Out:
#           date          traffic-source              traffic-details  users  \
# 0   2020-11-12        Internal traffic                         None   17.0
# 1   2020-11-12          Direct traffic                         None  147.0
# 2   2020-11-12            Link traffic             apps.shopify.com    1.0
# 3   2020-11-12            Link traffic                       be1.ru    1.0
# 4   2020-11-12            Link traffic          blog.saleslayer.com    1.0
# 5   2020-11-12            Link traffic                  chinafy.com    1.0
# 6   2020-11-12            Link traffic                   combot.org    2.0
# 7   2020-11-12            Link traffic    derdigitaleunternehmer.de    2.0
# 8   2020-11-12            Link traffic           destinonegocio.com    3.0
# 9   2020-11-12            Link traffic     dettalant.hatenablog.com    1.0
# 10  2020-11-12            Link traffic        developers.google.com    6.0
# 11  2020-11-12            Link traffic            direct.yandex.com    3.0
# 12  2020-11-12            Link traffic              disk.yandex.com    3.0
# 13  2020-11-12            Link traffic                    ecwid.com    1.0
# 14  2020-11-12            Link traffic             en.wikipedia.org    1.0
# 15  2020-11-12            Link traffic                 forobeta.com    1.0
# 16  2020-11-12            Link traffic                       g2.com    1.0
# 17  2020-11-12            Link traffic                geekbrains.ru    1.0
# 18  2020-11-12            Link traffic              keep.google.com    1.0
# 19  2020-11-12            Link traffic                lovesdata.com    1.0
# 20  2020-11-12            Link traffic           metrica.yandex.com    9.0
# 21  2020-11-12            Link traffic        metrica.yandex.com.tr    1.0
# 22  2020-11-12            Link traffic            metrika.yandex.ru    3.0
# 23  2020-11-12            Link traffic              mindmeister.com    1.0
# 24  2020-11-12            Link traffic           moe.yandex-team.ru    7.0
# 25  2020-11-12            Link traffic  negociosyemprendimiento.org    1.0
# 26  2020-11-12            Link traffic               own-ahrefs.com    2.0
# 27  2020-11-12            Link traffic          partner2.yandex.com    1.0
# 28  2020-11-12            Link traffic          passport.yandex.com   46.0
# 29  2020-11-12            Link traffic             paydarsamane.com    1.0
# 30  2020-11-12            Link traffic          qstyapps.weebly.com    1.0
# 31  2020-11-12            Link traffic            raffaelegaito.com    1.0
# 32  2020-11-12            Link traffic              saijogeorge.com    1.0
# 33  2020-11-12            Link traffic                    seolik.ru    1.0
# 34  2020-11-12            Link traffic             sites.google.com    4.0
# 35  2020-11-12            Link traffic                  smarters.ro    1.0
# 36  2020-11-12            Link traffic                smobayl.co.ua    5.0
# 37  2020-11-12            Link traffic                 webvisor.com    1.0
# 38  2020-11-12            Link traffic                   yandex.com    8.0
# 39  2020-11-12            Link traffic                    yandex.ru    1.0
# 40  2020-11-12            Link traffic                 yastatic.net    2.0
# 41  2020-11-12   Search engine traffic                   DuckDuckGo    2.0
# 42  2020-11-12   Search engine traffic                        Baidu    3.0
# 43  2020-11-12   Search engine traffic                       Yandex   25.0
# 44  2020-11-12   Search engine traffic                       Google  144.0
# 45  2020-11-12              Ad traffic                   Google Ads   12.0
# 46  2020-11-12              Ad traffic  Yandex.Direct: Undetermined   10.0
# 47  2020-11-12                    None                         None    1.0
# 48  2020-11-12  Social network traffic                    VKontakte    1.0
# 49  2020-11-12  Social network traffic                    Linked in    4.0
#
#     visits  pageviews  bounceRate  pageDepth  avgVisitDurationSeconds  \
# 0     17.0       29.0         5.9        1.7                     40.9
# 1    155.0      281.0        26.5        1.8                    146.2
# 2      1.0        1.0       100.0        1.0                      1.0
# 3      1.0        1.0       100.0        1.0                      1.0
# 4      1.0        2.0         0.0        2.0                    105.0
# 5      1.0        2.0         0.0        2.0                     12.0
# 6      2.0        3.0         0.0        1.5                     18.5
# 7      3.0        7.0         0.0        2.3                     24.3
# 8      3.0        4.0        66.7        1.3                      7.0
# 9      1.0        3.0         0.0        3.0                     65.0
# 10     6.0        8.0        66.7        1.3                    121.8
# 11     3.0        3.0        66.7        1.0                      5.3
# 12     3.0        4.0        66.7        1.3                     10.0
# 13     1.0        1.0       100.0        1.0                      1.0
# 14     1.0        4.0         0.0        4.0                     20.0
# 15     1.0        1.0       100.0        1.0                      2.0
# 16     1.0        2.0         0.0        2.0                     40.0
# 17     1.0        1.0         0.0        1.0                     23.0
# 18     1.0        1.0       100.0        1.0                      3.0
# 19     1.0        1.0       100.0        1.0                      2.0
# 20     9.0       18.0        22.2        2.0                    207.8
# 21     1.0        1.0         0.0        1.0                    612.0
# 22     3.0        4.0        33.3        1.3                     32.0
# 23     1.0        1.0         0.0        1.0                     15.0
# 24     9.0       22.0        44.4        2.4                    184.8
# 25     1.0        1.0       100.0        1.0                      8.0
# 26     2.0        2.0       100.0        1.0                      1.0
# 27     1.0        1.0       100.0        1.0                      0.0
# 28    46.0       62.0        60.9        1.3                     53.2
# 29     1.0        3.0         0.0        3.0                     31.0
# 30     1.0        1.0         0.0        1.0                     15.0
# 31     1.0        1.0         0.0        1.0                     18.0
# 32     1.0        1.0       100.0        1.0                      1.0
# 33     1.0        1.0       100.0        1.0                      0.0
# 34     6.0        7.0        33.3        1.2                     65.2
# 35     1.0        3.0         0.0        3.0                    128.0
# 36     6.0        8.0        50.0        1.3                     18.3
# 37     1.0        1.0       100.0        1.0                      1.0
# 38     8.0       14.0        25.0        1.8                     65.9
# 39     1.0        1.0         0.0        1.0                     15.0
# 40     2.0        2.0        50.0        1.0                      7.5
# 41     2.0        4.0        50.0        2.0                     31.5
# 42     3.0        4.0         0.0        1.3                    430.3
# 43    27.0       54.0        37.0        2.0                     50.5
# 44   161.0      281.0        25.5        1.7                    133.2
# 45    17.0       33.0        29.4        1.9                     60.9
# 46    11.0       13.0        45.5        1.2                     11.0
# 47     1.0        1.0       100.0        1.0                      0.0
# 48     1.0        1.0       100.0        1.0                      8.0
# 49     4.0        6.0        50.0        1.5                     19.5
#
#     avgUserPageviews
# 0                1.7
# 1                1.9
# 2                1.0
# 3                1.0
# 4                2.0
# 5                2.0
# 6                1.5
# 7                3.5
# 8                1.3
# 9                3.0
# 10               1.3
# 11               1.0
# 12               1.3
# 13               1.0
# 14               4.0
# 15               1.0
# 16               2.0
# 17               1.0
# 18               1.0
# 19               1.0
# 20               2.0
# 21               1.0
# 22               1.3
# 23               1.0
# 24               3.1
# 25               1.0
# 26               1.0
# 27               1.0
# 28               1.3
# 29               3.0
# 30               1.0
# 31               1.0
# 32               1.0
# 33               1.0
# 34               1.8
# 35               3.0
# 36               1.6
# 37               1.0
# 38               1.8
# 39               1.0
# 40               1.0
# 41               2.0
# 42               1.3
# 43               2.2
# 44               2.0
# 45               2.8
# 46               1.3
# 47               1.0
# 48               1.0
# 49               1.5

# %%
# Преобразуем столбец 'date' из строки в дату
df['date'] = pd.to_datetime(df['date'], format ='%Y-%m-%d').dt.date

# %%
# импорт датафрейма в csv. Подробнее https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html
# df.to_csv(r'D:\python\metrika.csv', index = False, sep=';')

# %%
# импорт датафрейма, как таблицы 'metrika_sources' в БД postgres, cхема 'p_stg'. Самому предварительно создавать в БД пустую таблицу не нужно
# postgresql://user:password@host:port/dbname 
engine = create_engine('postgresql://postgres:admin@localhost:5432/postgres')

# %%
df.to_sql('metrika_sources', engine, schema='p_stg', if_exists = 'append', index = False)
